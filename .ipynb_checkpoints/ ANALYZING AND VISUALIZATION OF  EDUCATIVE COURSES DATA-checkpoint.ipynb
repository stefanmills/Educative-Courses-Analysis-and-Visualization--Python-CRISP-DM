# %% [markdown]
# # PYTHON CLEANING OF EDUCATIVE COURSE

# %% [markdown]
# * Create a extraction file location
# * Unzip the CSV
# * Merge CSVs into one Excel
# * Cleaning (~Remove Rows with blank COURSE ID~,Published Time, Published Period, Published Date, Published Year, ~Remove URL Column~ and Publised TimeStamp,~Free or Paid~, ~Revenue~, ~CHANGE FROM Subject=Webdev to webdev~)
# * Change the column datatype
# * Change the name of the titles
# * Group by Subjects and Group By Levels
# * Create another sheet that will bring top 20 popular courses based on subs.( Add  Level, Free/Paid status, Content Duration, and Published Date)
# * Pivot Table
# * Visualize with connection frm powerbi.
# * Save visuals in a PDF format after.

# %%
import os
import zipfile
import pandas as pd
import glob
import matplotlib.pyplot as plt

# %%
zip_path="C:\\Users\\user\\Desktop\\python project\\dataset.zip"
ext_path="C:\\Users\\user\\Desktop\\python project"

#creating the extracted folder
if not os.path.exists(ext_path):
    os.makedirs(ext_path)
#Unziping file

with zipfile.ZipFile(zip_path,'r') as zipping:
    zipping.extractall(ext_path)

# %%
#Merging Files
all_files=glob.glob("C:\\Users\\user\\Desktop\\python project\\Data Sheet Educative Courses Export\\Data_Sheet*.csv")
all_files

df_list=[pd.read_csv(file) for file in all_files] #Created a list of dataframes form the all_files list
all_csvs=pd.concat(df_list,ignore_index=True)
all_csvs.to_csv('merged_data.csv')
all_csvs
# Out:
#       course_id                                       course_title  \
# 0       49798.0  Bitcoin or How I Learned to Stop Worrying and ...
# 1       48841.0    Accounting in 60 Minutes - A Brief Introduction
# 2      133536.0               Stock Market Investing for Beginners
# 3      151668.0                 Introduction to Financial Modeling
# 4      648826.0         The Complete Financial Analyst Course 2017
# ...         ...                                                ...
# 3676  1227578.0           Learning Path: The Road to Elasticsearch
# 3677  1277924.0                            Angular 4 Front To Back
# 3678  1248172.0            Essentials of Spring 5.0 for Developers
# 3679  1250934.0  Display and analyze GIS data on the web with L...
# 3680  1270222.0  Learning Path: Web Applications with Spring an...
#
#                                                     url  price  \
# 0     https://www.educative.com/bitcoin-or-how-i-lea...    0.0
# ...

# %% [markdown]
# ## EDA

# %%
#Creating duplicated dataset to work on
dup_data=all_csvs.copy()
dup_data
# Out:
#       course_id                                       course_title  \
# 0       49798.0  Bitcoin or How I Learned to Stop Worrying and ...
# 1       48841.0    Accounting in 60 Minutes - A Brief Introduction
# 2      133536.0               Stock Market Investing for Beginners
# 3      151668.0                 Introduction to Financial Modeling
# 4      648826.0         The Complete Financial Analyst Course 2017
# ...         ...                                                ...
# 3676  1227578.0           Learning Path: The Road to Elasticsearch
# 3677  1277924.0                            Angular 4 Front To Back
# 3678  1248172.0            Essentials of Spring 5.0 for Developers
# 3679  1250934.0  Display and analyze GIS data on the web with L...
# 3680  1270222.0  Learning Path: Web Applications with Spring an...
#
#                                                     url  price  \
# 0     https://www.educative.com/bitcoin-or-how-i-lea...    0.0
# ...

# %%
dup_data.shape
# Out:
# (3681, 12)

# %%
dup_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3681 entries, 0 to 3680
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3676 non-null   float64
#  1   course_title         3676 non-null   object
#  2   url                  3676 non-null   object
#  3   price                3676 non-null   float64
#  4   num_subscribers      3676 non-null   float64
#  5   num_reviews          3676 non-null   float64
#  6   num_lectures         3676 non-null   float64
#  7   level                3676 non-null   object
#  8   Rating               3677 non-null   float64
#  9   content_duration     3676 non-null   float64
#  10  published_timestamp  3676 non-null   object
#  11  subject              3677 non-null   object
# dtypes: float64(7), object(5)
# memory usage: 345.2+ KB

# %%
dup_data=dup_data.drop(columns='url')
dup_data.head()
# Out:
#    course_id                                       course_title  price  \
# 0    49798.0  Bitcoin or How I Learned to Stop Worrying and ...    0.0
# 1    48841.0    Accounting in 60 Minutes - A Brief Introduction    0.0
# 2   133536.0               Stock Market Investing for Beginners    0.0
# 3   151668.0                 Introduction to Financial Modeling    0.0
# 4   648826.0         The Complete Financial Analyst Course 2017  195.0
#
#    num_subscribers  num_reviews  num_lectures           level  Rating  \
# 0          65576.0        936.0          24.0      All Levels    0.56
# 1          56659.0       4397.0          16.0  Beginner Level    0.95
# 2          50855.0       2698.0          15.0      All Levels    0.91
# 3          29167.0       1463.0           8.0      All Levels    0.18
# 4          24481.0       2347.0         174.0      All Levels    0.37
#
#    content_duration   published_timestamp           subject
# ...

# %%
#Dropping Columns with null columns
dup_data=dup_data.dropna(subset='course_id')
dup_data=dup_data.reset_index(drop=True)
dup_data
# Out:
#       course_id                                       course_title  price  \
# 0       49798.0  Bitcoin or How I Learned to Stop Worrying and ...    0.0
# 1       48841.0    Accounting in 60 Minutes - A Brief Introduction    0.0
# 2      133536.0               Stock Market Investing for Beginners    0.0
# 3      151668.0                 Introduction to Financial Modeling    0.0
# 4      648826.0         The Complete Financial Analyst Course 2017  195.0
# ...         ...                                                ...    ...
# 3671  1227578.0           Learning Path: The Road to Elasticsearch  200.0
# 3672  1277924.0                            Angular 4 Front To Back   40.0
# 3673  1248172.0            Essentials of Spring 5.0 for Developers  125.0
# 3674  1250934.0  Display and analyze GIS data on the web with L...  100.0
# 3675  1270222.0  Learning Path: Web Applications with Spring an...  200.0
#
#       num_subscribers  num_reviews  num_lectures           level  Rating  \
# ...

# %%
dup_data.shape
# Out:
# (3676, 11)

# %%
dup_data.isnull().sum()
# Out:
# course_id              0
# course_title           0
# price                  0
# num_subscribers        0
# num_reviews            0
# num_lectures           0
# level                  0
# Rating                 0
# content_duration       0
# published_timestamp    0
# subject                0
# dtype: int64

# %%
#Checking the number of duplicates
dup_data.duplicated().sum()
# Out:
# 0

# %%
dup_data.describe()
# Out:
#           course_id        price  num_subscribers   num_reviews  num_lectures  \
# count  3.676000e+03  3676.000000      3676.000000   3676.000000   3676.000000
# mean   6.757535e+05    66.115343      3199.260881    156.309848     40.129761
# std    3.431304e+05    61.056073      9486.582966    935.674518     50.398507
# min    8.324000e+03     0.000000         0.000000      0.000000      0.000000
# 25%    4.074740e+05    20.000000       112.000000      4.000000     15.000000
# 50%    6.876920e+05    45.000000       912.500000     18.000000     25.000000
# 75%    9.608140e+05    95.000000      2558.000000     67.000000     46.000000
# max    1.282064e+06   200.000000    268923.000000  27445.000000    779.000000
#
#             Rating  content_duration
# count  3676.000000       3676.000000
# mean      0.610868          4.096137
# std       0.334287          6.054948
# min       0.000000          0.000000
# 25%       0.280000          1.000000
# 50%       0.760000          2.000000
# ...

# %%
dup_data.describe(include='object')
# Out:
#                          course_title       level   published_timestamp  \
# count                            3676        3676                  3676
# unique                           3663           4                  3672
# top     Acoustic Blues Guitar Lessons  All Levels  2017-02-07T17:20:39Z
# freq                                3        1925                     2
#
#                          subject
# count                       3676
# unique                         4
# top     Subject: Web Development
# freq                        1203

# %%
dup_data['revenue']=dup_data['price']*dup_data['num_subscribers']
dup_data
# Out:
#       course_id                                       course_title  price  \
# 0       49798.0  Bitcoin or How I Learned to Stop Worrying and ...    0.0
# 1       48841.0    Accounting in 60 Minutes - A Brief Introduction    0.0
# 2      133536.0               Stock Market Investing for Beginners    0.0
# 3      151668.0                 Introduction to Financial Modeling    0.0
# 4      648826.0         The Complete Financial Analyst Course 2017  195.0
# ...         ...                                                ...    ...
# 3671  1227578.0           Learning Path: The Road to Elasticsearch  200.0
# 3672  1277924.0                            Angular 4 Front To Back   40.0
# 3673  1248172.0            Essentials of Spring 5.0 for Developers  125.0
# 3674  1250934.0  Display and analyze GIS data on the web with L...  100.0
# 3675  1270222.0  Learning Path: Web Applications with Spring an...  200.0
#
#       num_subscribers  num_reviews  num_lectures           level  Rating  \
# ...

# %%
dup_data['subject']=dup_data['subject'].str.strip('Subject:')
dup_data
# Out:
#       course_id                                       course_title  price  \
# 0       49798.0  Bitcoin or How I Learned to Stop Worrying and ...    0.0
# 1       48841.0    Accounting in 60 Minutes - A Brief Introduction    0.0
# 2      133536.0               Stock Market Investing for Beginners    0.0
# 3      151668.0                 Introduction to Financial Modeling    0.0
# 4      648826.0         The Complete Financial Analyst Course 2017  195.0
# ...         ...                                                ...    ...
# 3671  1227578.0           Learning Path: The Road to Elasticsearch  200.0
# 3672  1277924.0                            Angular 4 Front To Back   40.0
# 3673  1248172.0            Essentials of Spring 5.0 for Developers  125.0
# 3674  1250934.0  Display and analyze GIS data on the web with L...  100.0
# 3675  1270222.0  Learning Path: Web Applications with Spring an...  200.0
#
#       num_subscribers  num_reviews  num_lectures           level  Rating  \
# ...

# %%
dup_data['Free_or_Paid']=dup_data['price'].apply(lambda x: 'Free' if x ==0 else 'Paid')
dup_data
# Out:
#       course_id                                       course_title  price  \
# 0       49798.0  Bitcoin or How I Learned to Stop Worrying and ...    0.0
# 1       48841.0    Accounting in 60 Minutes - A Brief Introduction    0.0
# 2      133536.0               Stock Market Investing for Beginners    0.0
# 3      151668.0                 Introduction to Financial Modeling    0.0
# 4      648826.0         The Complete Financial Analyst Course 2017  195.0
# ...         ...                                                ...    ...
# 3671  1227578.0           Learning Path: The Road to Elasticsearch  200.0
# 3672  1277924.0                            Angular 4 Front To Back   40.0
# 3673  1248172.0            Essentials of Spring 5.0 for Developers  125.0
# 3674  1250934.0  Display and analyze GIS data on the web with L...  100.0
# 3675  1270222.0  Learning Path: Web Applications with Spring an...  200.0
#
#       num_subscribers  num_reviews  num_lectures           level  Rating  \
# ...

# %%
#Splitting the published_timestamp to published_date and published_time
dup_data[['published_date','published_time']]=dup_data['published_timestamp'].str.split('T',expand=True)
dup_data.head()
# Out:
#    course_id                                       course_title  price  \
# 0    49798.0  Bitcoin or How I Learned to Stop Worrying and ...    0.0
# 1    48841.0    Accounting in 60 Minutes - A Brief Introduction    0.0
# 2   133536.0               Stock Market Investing for Beginners    0.0
# 3   151668.0                 Introduction to Financial Modeling    0.0
# 4   648826.0         The Complete Financial Analyst Course 2017  195.0
#
#    num_subscribers  num_reviews  num_lectures           level  Rating  \
# 0          65576.0        936.0          24.0      All Levels    0.56
# 1          56659.0       4397.0          16.0  Beginner Level    0.95
# 2          50855.0       2698.0          15.0      All Levels    0.91
# 3          29167.0       1463.0           8.0      All Levels    0.18
# 4          24481.0       2347.0         174.0      All Levels    0.37
#
#    content_duration   published_timestamp         subject    revenue  \
# ...

# %%
dup_data=dup_data.drop(columns='published_timestamp')
dup_data
# Out:
#       course_id                                       course_title  price  \
# 0       49798.0  Bitcoin or How I Learned to Stop Worrying and ...    0.0
# 1       48841.0    Accounting in 60 Minutes - A Brief Introduction    0.0
# 2      133536.0               Stock Market Investing for Beginners    0.0
# 3      151668.0                 Introduction to Financial Modeling    0.0
# 4      648826.0         The Complete Financial Analyst Course 2017  195.0
# ...         ...                                                ...    ...
# 3671  1227578.0           Learning Path: The Road to Elasticsearch  200.0
# 3672  1277924.0                            Angular 4 Front To Back   40.0
# 3673  1248172.0            Essentials of Spring 5.0 for Developers  125.0
# 3674  1250934.0  Display and analyze GIS data on the web with L...  100.0
# 3675  1270222.0  Learning Path: Web Applications with Spring an...  200.0
#
#       num_subscribers  num_reviews  num_lectures           level  Rating  \
# ...

# %%
dup_data['published_time']=dup_data['published_time'].str.strip('Z')
dup_data
# Out:
#       course_id                                       course_title  price  \
# 0       49798.0  Bitcoin or How I Learned to Stop Worrying and ...    0.0
# 1       48841.0    Accounting in 60 Minutes - A Brief Introduction    0.0
# 2      133536.0               Stock Market Investing for Beginners    0.0
# 3      151668.0                 Introduction to Financial Modeling    0.0
# 4      648826.0         The Complete Financial Analyst Course 2017  195.0
# ...         ...                                                ...    ...
# 3671  1227578.0           Learning Path: The Road to Elasticsearch  200.0
# 3672  1277924.0                            Angular 4 Front To Back   40.0
# 3673  1248172.0            Essentials of Spring 5.0 for Developers  125.0
# 3674  1250934.0  Display and analyze GIS data on the web with L...  100.0
# 3675  1270222.0  Learning Path: Web Applications with Spring an...  200.0
#
#       num_subscribers  num_reviews  num_lectures           level  Rating  \
# ...

# %%
#Converting from yyyy/mm/dd to dd/mm/yyyy in the published_date column
dup_data['published_date']=pd.to_datetime(dup_data['published_date']).dt.strftime('%d/%m/%Y')
dup_data
# Out:
#       course_id                                       course_title  price  \
# 0       49798.0  Bitcoin or How I Learned to Stop Worrying and ...    0.0
# 1       48841.0    Accounting in 60 Minutes - A Brief Introduction    0.0
# 2      133536.0               Stock Market Investing for Beginners    0.0
# 3      151668.0                 Introduction to Financial Modeling    0.0
# 4      648826.0         The Complete Financial Analyst Course 2017  195.0
# ...         ...                                                ...    ...
# 3671  1227578.0           Learning Path: The Road to Elasticsearch  200.0
# 3672  1277924.0                            Angular 4 Front To Back   40.0
# 3673  1248172.0            Essentials of Spring 5.0 for Developers  125.0
# 3674  1250934.0  Display and analyze GIS data on the web with L...  100.0
# 3675  1270222.0  Learning Path: Web Applications with Spring an...  200.0
#
#       num_subscribers  num_reviews  num_lectures           level  Rating  \
# ...

# %%
#Converting the published_time to a time datatype
dup_data['published_time']=pd.to_timedelta(dup_data['published_time'])
dup_data
# Out:
#       course_id                                       course_title  price  \
# 0       49798.0  Bitcoin or How I Learned to Stop Worrying and ...    0.0
# 1       48841.0    Accounting in 60 Minutes - A Brief Introduction    0.0
# 2      133536.0               Stock Market Investing for Beginners    0.0
# 3      151668.0                 Introduction to Financial Modeling    0.0
# 4      648826.0         The Complete Financial Analyst Course 2017  195.0
# ...         ...                                                ...    ...
# 3671  1227578.0           Learning Path: The Road to Elasticsearch  200.0
# 3672  1277924.0                            Angular 4 Front To Back   40.0
# 3673  1248172.0            Essentials of Spring 5.0 for Developers  125.0
# 3674  1250934.0  Display and analyze GIS data on the web with L...  100.0
# 3675  1270222.0  Learning Path: Web Applications with Spring an...  200.0
#
#       num_subscribers  num_reviews  num_lectures           level  Rating  \
# ...

# %%
dup_data['published_time']=dup_data['published_time'].drop(columns='0 days ')
dup_data
# Out:
#       course_id                                       course_title  price  \
# 0       49798.0  Bitcoin or How I Learned to Stop Worrying and ...    0.0
# 1       48841.0    Accounting in 60 Minutes - A Brief Introduction    0.0
# 2      133536.0               Stock Market Investing for Beginners    0.0
# 3      151668.0                 Introduction to Financial Modeling    0.0
# 4      648826.0         The Complete Financial Analyst Course 2017  195.0
# ...         ...                                                ...    ...
# 3671  1227578.0           Learning Path: The Road to Elasticsearch  200.0
# 3672  1277924.0                            Angular 4 Front To Back   40.0
# 3673  1248172.0            Essentials of Spring 5.0 for Developers  125.0
# 3674  1250934.0  Display and analyze GIS data on the web with L...  100.0
# 3675  1270222.0  Learning Path: Web Applications with Spring an...  200.0
#
#       num_subscribers  num_reviews  num_lectures           level  Rating  \
# ...

# %%
dup_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3676 entries, 0 to 3675
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   course_id         3676 non-null   float64
#  1   course_title      3676 non-null   object
#  2   price             3676 non-null   float64
#  3   num_subscribers   3676 non-null   float64
#  4   num_reviews       3676 non-null   float64
#  5   num_lectures      3676 non-null   float64
#  6   level             3676 non-null   object
#  7   Rating            3676 non-null   float64
#  8   content_duration  3676 non-null   float64
#  9   subject           3676 non-null   object
#  10  revenue           3676 non-null   float64
#  11  Free_or_Paid      3676 non-null   object
#  12  published_date    3676 non-null   object
#  13  published_time    3676 non-null   timedelta64[ns]
# dtypes: float64(8), object(5), timedelta64[ns](1)
# memory usage: 402.2+ KB

# %%
dup_data.corr(numeric_only=True)

# %% [markdown]
# # Data Cleaning

# %%
#Create a duplicate data
cleaned_data=merged_df.copy()


#Removing duplicate
cleaned_data.drop_duplicates() #shape is =(3681, 12)

#Removing URL Column
cleaned_data=cleaned_data.drop(columns='url')
cleaned_data #shape is =(3681, 11)

# %%
#Checking the number of blanks per column
print(cleaned_data.isnull().sum())

# %%
#Removing all rows with blanks in it
cleaned_data=cleaned_data.dropna()
print(cleaned_data.isnull().sum()) #Number of blanks in each column
cleaned_data.shape  #New Shape =(3676, 11)

# %%
#Replacing subject column record 'Subject: Web Development' to 'Web Development'
cleaned_data['subject']=cleaned_data['subject'].str.lstrip('Subject: ')
cleaned_data

# %%
test=cleaned_data
test['Revenue']=test['price']*test['num_subscribers']
test

# %%
test['Course Category']=test['price'].apply(lambda x:'Free' if x==0 else 'Paid' )

# %%
test

# %%
test.pivot_table
